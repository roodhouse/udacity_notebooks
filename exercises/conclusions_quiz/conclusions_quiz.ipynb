# %% [markdown]
# # Drawing Conclusions Quiz
# Use the space below to explore the `store_data.csv` dataset to answer the quiz questions below.
#   * Which store has the highest total sales for the final month of data?
#   * Which store makes the most sales on average?
#   * Which store sells the most during the week of March 13th, 2016?
#   * In what week does store C make its worst sales?
#   * Which store has the most sales in the latest 3-month period?

# %%
# imports and load data
import pandas as pd

df = pd.read_csv('store_data.csv')
df.head()
# Out:
#          week  storeA  storeB  storeC  storeD  storeE
# 0  2014-05-04    2643    8257    3893    6231    1294
# 1  2014-05-11    6444    5736    5634    7092    2907
# 2  2014-05-18    9646    2552    4253    5447    4736
# 3  2014-05-25    5960   10740    8264    6063     949
# 4  2014-06-01    7412    7374    3208    3985    3023

# %%
# explore data by creating histograms on the entire DataFrame
df.hist(figsize=(8,8));

# %%
# Use tail to find the end of the dataset to locate where the last month is via its index
df.tail(20)
# Out:
#            week  storeA  storeB  storeC  storeD  storeE  total
# 180  2017-10-15    8556   11984    4792    5995    2508  25127
# 181  2017-10-22    3751     697    3990    4236     360  25127
# 182  2017-10-29    4997    9759    4290    4568    2393  25127
# 183  2017-11-05   12785    1800    6163    5157     578  25127
# 184  2017-11-12     137   12261    5455    7695    2599  25127
# 185  2017-11-19    9960    8529    4501    7631     505  25127
# 186  2017-11-26    6866    5011    5401    4736    3232  25127
# 187  2017-12-03    5179    3850    6121    6778     113  25127
# 188  2017-12-10    9348    5624    5446    5448     227  25127
# 189  2017-12-17    5310    8647    5680    7049    3578  25127
# 190  2017-12-24    8976    9503    6240    3882    2890  25127
# 191  2017-12-31   11875    1527    6711    5265    1701  25127
# 192  2018-01-07    8978   11312    4158    5019    3842  25127
# 193  2018-01-14    6963    4014    4215    7153    3097  25127
# 194  2018-01-21    5553    3971    3761    6255    3071  25127
# 195  2018-01-28     282    6351    7759    5558    1028  25127
# 196  2018-02-04    4853    6503    4187    5956    1458  25127
# 197  2018-02-11    9202    3677    4540    6186     243  25127
# 198  2018-02-18    3512    7511    4151    5596    3501  25127
# 199  2018-02-25    7560    6904    3569    5045    2585  25127

# %%
# Use iloc to create a slice of the last month and sum up the weeks
# to find the total sales for the last month
df.iloc[196:, 1:].sum()
# Out:
# storeA     25127
# storeB     24595
# storeC     16447
# storeD     22783
# storeE      7787
# total     100508
# dtype: int64

# %%
# Use the mean method to find the average sales for each store
df.mean(numeric_only=True)
# Out:
# storeA     5865.480
# storeB     6756.710
# storeC     4942.105
# storeD     5431.405
# storeE     2580.025
# total     25127.000
# dtype: float64

# %%
# Find the sales of all stores by filtering on the week of march 13, 2016
df[df['week'] == '2016-03-13']
# Out:
#           week  storeA  storeB  storeC  storeD  storeE  total
# 97  2016-03-13    2054    1390    5112    5513    2536  25127

# %%
# Use the min method to filter the dataset to find the worst week for store C
df[df['storeC'] == df['storeC'].min()]
# Out:
#          week  storeA  storeB  storeC  storeD  storeE  total
# 9  2014-07-06    8567    3228     927    3277     168  25127

# %%
# Filter the DataFrame on the most recent 3 month period. You can filter by selecting
# greater than or equal to 2017-12-01
last_three_months = df[df['week'] >= '2017-12-01']
# Find the total sales during this 3 month 
last_three_months.iloc[:, 1:].sum()  # exclude sum of week column
# Out:
# storeA     87591
# storeB     79394
# storeC     66538
# storeD     75190
# storeE     27334
# total     326651
# dtype: int64
